# %% [markdown]
# # PySpark Interview: UDFs & Custom Logic
#
# **Task:** Create and optimize User Defined Functions

# %%
# Import libraries
from pyspark.sql.functions import udf
from pyspark.sql.types import *

# %%
# Create SparkSession

# %% [markdown]
# ## Problem 1: Simple UDF
# *Create a UDF to transform text*

# %%
# Define Python function

# Register as UDF

# Apply to DataFrame:

# %% [markdown]
# ## Problem 2: UDF with Complex Return Type
# *Return StructType or ArrayType*

# %%
# Define schema

# Your solution:

# %% [markdown]
# ## Problem 3: Pandas UDF (Vectorized)
# *Optimize UDF performance with pandas_udf*

# %%
# Your solution:

# %% [markdown]
# ## Problem 4: Avoid UDF When Possible
# *Rewrite UDF logic using built-in functions*

# %%
# Slow UDF approach:

# Optimized built-in approach:
