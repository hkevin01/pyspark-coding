# %% [markdown]
# # PySpark Interview: Window Functions
#
# **Task:** Use window functions for advanced analytics

# %%
# Import libraries
from pyspark.sql import Window
from pyspark.sql.functions import *

# %%
# Create SparkSession

# %% [markdown]
# ## Problem 1: Running Total
# *Calculate cumulative sum over a partition*

# %%
# Sample data

# Your solution:

# %% [markdown]
# ## Problem 2: Rank by Category
# *Rank items within each category*

# %%
# Your solution:

# %% [markdown]
# ## Problem 3: Moving Average
# *Calculate rolling average over N rows*

# %%
# Your solution:

# %% [markdown]
# ## Problem 4: Lag/Lead Operations
# *Compare current row with previous/next rows*

# %%
# Your solution:
