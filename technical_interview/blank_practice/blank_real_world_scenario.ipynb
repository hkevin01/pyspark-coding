# %% [markdown]
# # PySpark Interview: Real-World Scenario
#
# **Scenario:** E-commerce data analysis pipeline

# %%
# Import libraries

# %%
# Create SparkSession

# %% [markdown]
# ## Business Problem
#
# You have:
# - `customers` (customer_id, name, country)
# - `orders` (order_id, customer_id, order_date, amount)
# - `products` (product_id, product_name, category)
# - `order_items` (order_id, product_id, quantity, price)
#
# **Task:** Find top 10 customers by total spending in last 90 days, broken down by product category

# %%
# Step 1: Load data (assume already loaded)
# customers = ...
# orders = ...
# products = ...
# order_items = ...

# %%
# Step 2: Filter to last 90 days

# %%
# Step 3: Join tables

# %%
# Step 4: Calculate spending by customer and category

# %%
# Step 5: Get top 10 customers

# %%
# Step 6: Format and display results
