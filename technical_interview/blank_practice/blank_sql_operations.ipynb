# %% [markdown]
# # PySpark Interview: SQL Operations
#
# **Task:** Write complex SQL queries in PySpark

# %%
# Import libraries

# %%
# Create SparkSession

# %% [markdown]
# ## Problem 1: Subquery
# *Use subquery to filter data*

# %%
# Register DataFrame as temp view
# df.createOrReplaceTempView('table_name')

# Your SQL solution:

# %% [markdown]
# ## Problem 2: Multiple Joins
# *Join 3+ tables with different join types*

# %%
# Your solution:

# %% [markdown]
# ## Problem 3: Complex WHERE Clause
# *Use CASE WHEN, IN, NOT IN, EXISTS*

# %%
# Your solution:

# %% [markdown]
# ## Problem 4: CTE (Common Table Expression)
# *Use WITH clause for readable queries*

# %%
# Your solution:
