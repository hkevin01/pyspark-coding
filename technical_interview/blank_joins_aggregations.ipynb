# %% [markdown]
# # PySpark Interview: Joins & Aggregations
#
# **Task:** Combine and aggregate data from multiple sources

# %%
# Import libraries

# %%
# Create SparkSession

# %% [markdown]
# ## Problem 1: Inner Join
# *Join two DataFrames on a key*

# %%
# Create sample DataFrames
# df1 = ...
# df2 = ...

# Your solution:

# %% [markdown]
# ## Problem 2: Left Join with Null Handling
# *Perform left join and handle missing values*

# %%
# Your solution:

# %% [markdown]
# ## Problem 3: GroupBy Aggregation
# *Calculate multiple aggregates per group*

# %%
# Your solution:

# %% [markdown]
# ## Problem 4: Complex Aggregation
# *Use multiple grouping columns and aggregate functions*

# %%
# Your solution:
