# %% [markdown]
# # PySpark Interview: Performance Optimization
#
# **Task:** Optimize slow Spark jobs

# %%
# Import libraries

# %%
# Create SparkSession with optimizations

# %% [markdown]
# ## Problem 1: Partition Optimization
# *Optimize data partitioning for better performance*

# %%
# Inefficient code:
# df.repartition(200)

# Your optimized solution:

# %% [markdown]
# ## Problem 2: Broadcast Join
# *Use broadcast for small table joins*

# %%
# Your solution:

# %% [markdown]
# ## Problem 3: Cache Strategy
# *Decide when to cache DataFrames*

# %%
# Your solution:

# %% [markdown]
# ## Problem 4: Avoid Shuffles
# *Rewrite query to minimize shuffles*

# %%
# Inefficient code with shuffle:

# Your optimized solution:
