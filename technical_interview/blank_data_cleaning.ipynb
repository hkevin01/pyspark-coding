# %% [markdown]
# # PySpark Interview: Data Cleaning & Transformations
#
# **Task:** Clean and transform messy data

# %%
# Import libraries

# %%
# Create SparkSession

# %% [markdown]
# ## Problem 1: Remove Duplicates
# *Remove duplicate rows based on specific columns*

# %%
# Sample data with duplicates

# Your solution:

# %% [markdown]
# ## Problem 2: Handle Missing Values
# *Fill or drop null values appropriately*

# %%
# Data with nulls

# Your solution:

# %% [markdown]
# ## Problem 3: String Transformations
# *Clean and standardize string columns*

# %%
# Data with messy strings

# Your solution:

# %% [markdown]
# ## Problem 4: Type Conversions
# *Convert column types correctly*

# %%
# Data with wrong types

# Your solution:
